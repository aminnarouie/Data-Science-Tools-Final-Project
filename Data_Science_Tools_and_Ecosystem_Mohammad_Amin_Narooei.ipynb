# %% [markdown]
# # Data Science Tools and Ecosystem
#
# *Final Project – JupyterLite Notebook*

# %% [markdown]
# ## Introduction
# In this notebook, I will summarize some of the key tools used in data science.
# You will find examples of common **languages**, popular **libraries**, and a small **table of tools**.
# I will also demonstrate a couple of simple **arithmetic expressions** in Python.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - **NumPy**, **pandas**, **Matplotlib**, **Seaborn**
# - **scikit-learn**, **TensorFlow**, **PyTorch**
# - **ggplot2** (R), **dplyr** (R), **caret** (R)

# %% [markdown]
# ## Data Science Tools
# | Category        | Tool                | Typical Use                              |
# |-----------------|---------------------|-------------------------------------------|
# | IDE/Notebook    | JupyterLab          | Interactive coding and documentation     |
# | IDE/Notebook    | JupyterLite         | In-browser notebooks (no local install)  |
# | IDE/Notebook    | RStudio             | R IDE and notebooks                      |
# | Big Data        | Apache Spark        | Distributed processing, ML at scale      |
# | Big Data        | Hadoop (HDFS/YARN)  | Distributed storage & resource mgmt      |
# | Workflow/ETL    | Apache Airflow      | Orchestration and scheduling             |

# %% [markdown]
# ## Examples of Evaluating Arithmetic Expressions in Python
# Below are a few simple expressions to demonstrate multiplication, addition, and unit conversion.

# %%
# Multiply and add numbers
a = 6
b = 7
c = 15

product = a * b
sum_ = product + c

product, sum_

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# - List common **data science languages** and **libraries**
# - Present a small **table** of popular **data science tools**
# - Run simple **arithmetic expressions** in Python (multiply/add; minutes → hours)
# - Practice writing clean **Markdown** in a Jupyter notebook

# %% [markdown]
# ## Author
# **Name:** Mohammad Amin Narooei
# **Date:** November 12, 2025

# %% [markdown]
# ## Sharing via GitHub (Guide)
# 1. **Download** this notebook as `.ipynb` from JupyterLite or your local environment.
# 2. On **GitHub**, create a new public repository (or use an existing one).
# 3. Click **Add file → Upload files**, and upload the `.ipynb`.
# 4. After the upload, click **Commit changes**.
# 5. Copy the **public URL** of the notebook in your repo to share for peer review.

# %% [markdown]
# ## Screenshot Reminder
# For peer review, take a screenshot of the **first page** of this notebook showing the title and any visible outputs.
# - Windows: `Alt` + `PrintScreen` (or `Win` + `Shift` + `S`)
# - macOS: `Shift` + `Command` + `3`
# - Save as **.png** or **.jpg** and upload per the submission instructions.
